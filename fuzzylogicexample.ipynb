# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Grafiklerin Matrislere dönüştürülmesi
camasirsertligi=[["sert",[0,20,40],[1,1,0]],
                 ["h.sert",[20,40,60],[0,1,0]],
                 ["h.yumuşak",[40,60,80],[0,1,0]],
                 ["yumuşak",[60,80,100],[0,1,1]]]

camasirmiktari=[["az",[0,1,3],[1,1,0]],
                ["normal",[1,3,5],[0,1,0]],
                ["çok",[3,5,6],[0,1,1]]]

devir=         [["hassas",[0,400,600],[1,1,0]],
                ["hafif",[400,600,800],[0,1,0]],
                ["normal",[600,800,1000],[0,1,0]],
                ["güçlü",[800,1000,1200],[0,1,1]]]

aranan_sertlik = 65
aranan_miktar = 4

# %%
#üyelik fonk. grafiklerinin çizilmesi

fig, ax = plt.subplots() 
ax.set_title('Çamaşır Sertliği Verileri')
ax.plot(camasirsertligi[0][1],camasirsertligi[0][2],label="sert", color="g")
ax.plot(camasirsertligi[1][1],camasirsertligi[1][2],label="h.sert", color="r")
ax.plot(camasirsertligi[2][1],camasirsertligi[2][2],label="h.yumuşak", color="b")
ax.plot(camasirsertligi[3][1],camasirsertligi[3][2],label="yumuşak",color="k")
ax.scatter(aranan_sertlik, 0.25, color='orange')
ax.scatter(aranan_sertlik, 0.75, color='orange', label='sertlik değeri') #fonk. bulunan değerler
ax.axvline(x=aranan_sertlik, color='orange', linestyle='--', label='x=65')
ax.legend()
fig, ax = plt.subplots() 
ax.set_title('Çamaşır Miktari Verileri')
ax.plot(camasirmiktari[0][1],camasirmiktari[0][2],label="az",color="g")
ax.plot(camasirmiktari[1][1],camasirmiktari[1][2],label="normal",color="r")
ax.plot(camasirmiktari[2][1],camasirmiktari[2][2],label="çok",color="b")
ax.axvline(x=aranan_miktar, color='orange', linestyle='--', label='x=4')
ax.scatter(aranan_miktar, 0.5, color='orange', label='miktar')#fonk. bulunan değerler
ax.legend()
fig, ax = plt.subplots() 
ax.set_title('Çamaşır Devir Verileri')
ax.plot(devir[0][1],devir[0][2],label="hassas",color="g")
ax.plot(devir[1][1],devir[1][2],label="hafif",color="r")
ax.plot(devir[2][1],devir[2][2],label="normal",color="b")
ax.plot(devir[3][1],devir[3][2],label="güçlü",color="k")
ax.legend()


plt.show()

# %%
aranan_sertlik=50
def camasirsertlikuye(camasirsertligi,aranan_sertlik):
    uyelikler=list()
    s = camasirsertligi[0][0]
    hs =camasirsertligi[1][0]
    hy= camasirsertligi[2][0]
    y=camasirsertligi[3][0]
    
    #sertin elemanı mı
    if aranan_sertlik >= camasirsertligi[0][1][0] and aranan_sertlik <= camasirsertligi[0][1][2]:
      
        if aranan_sertlik >= camasirsertligi[0][1][0] and aranan_sertlik <= camasirsertligi[0][1][1]: 
            uyelikler.append(s)
            uyelikler.append(1) 
        else:
           x=1-((1-0)*(camasirsertligi[0][1][2]-aranan_sertlik))/(camasirsertligi[0][1][2]-camasirsertligi[0][1][1])
           uyelikler.append(hs)
           uyelikler.append(x)
       
    #h.sertin elemanı mı
    if aranan_sertlik >= camasirsertligi[1][1][0] and aranan_sertlik <= camasirsertligi[1][1][2]:
        
        
        if aranan_sertlik >= camasirsertligi[1][1][0] and aranan_sertlik <= camasirsertligi[1][1][1]:
           x=1-((1-0)*(camasirsertligi[1][1][0]-aranan_sertlik))/(camasirsertligi[1][1][0]-camasirsertligi[1][1][1])
           
           uyelikler.append(s) 
           uyelikler.append(x) 
           
        else:
           x=1-((1-0)*(camasirsertligi[1][1][2]-aranan_sertlik))/(camasirsertligi[1][1][2]-camasirsertligi[1][1][1])
           uyelikler.append(hy)
           
           uyelikler.append(x)
           
       
    #h.yumuşağın elemanı mı
    if aranan_sertlik >= camasirsertligi[2][1][0] and aranan_sertlik <= camasirsertligi[2][1][2]:
       
       if aranan_sertlik >= camasirsertligi[2][1][0] and aranan_sertlik <= camasirsertligi[2][1][1]:
           x=1-((1-0)*(camasirsertligi[2][1][0]-aranan_sertlik))/(camasirsertligi[2][1][0]-camasirsertligi[2][1][1])
           #uyelikler.insert(0,b)
           uyelikler.append(hs)
           uyelikler.append(x) 
           
       else:
           x=1-((1-0)*(camasirsertligi[2][1][2]-aranan_sertlik))/(camasirsertligi[2][1][2]-camasirsertligi[2][1][1])
           #uyelikler.insert(0,b)
           uyelikler.append(y)
           uyelikler.append(x)
           
       
    #yumuşağın elemanı mı
    if aranan_sertlik >= camasirsertligi[3][1][0] and aranan_sertlik <= camasirsertligi[3][1][2]:
       
       if aranan_sertlik >= camasirsertligi[3][1][0] and aranan_sertlik <= camasirsertligi[3][1][1]:
           x=1-((1-0)*(camasirsertligi[3][1][0]-aranan_sertlik))/(camasirsertligi[3][1][0]-camasirsertligi[3][1][1])
           
           uyelikler.append(hy)
           uyelikler.append(x) 
           
       else:
           uyelikler.append(hy)
           uyelikler.append(1)
           
           
    return uyelikler

camasirsertlikuye(camasirsertligi,aranan_sertlik)
# Out:
# ['h.yumuşak', 0.5, 'h.sert', 0.5]

# %%
# sertlik üyelikleri fonk
def camasirsertlikuye(camasirsertligi,aranan_sertlik):
    uyelikler = list()

    if aranan_sertlik >= camasirsertligi[0][1][0] and aranan_sertlik <= camasirsertligi[0][1][2]: #0-40 aralığı
        uyelikler.append(camasirsertligi[0][0]) #sert
        if aranan_sertlik >= camasirsertligi[0][1][0] and aranan_sertlik <= camasirsertligi[0][1][1]:#0-20 arası 1 
            uyelikler.append(1) # sertlik üyelik derecesi 1
        else:
            x = 1 - ((1-0)*(camasirsertligi[0][1][2]-aranan_sertlik))/(camasirsertligi[0][1][2]-camasirsertligi[0][1][0])
            uyelikler.append(x) #benzerlik ?
    if aranan_sertlik >= camasirsertligi[1][1][0] and aranan_sertlik <= camasirsertligi[1][1][2]: #20-60
       uyelikler.append(camasirsertligi[1][0]) #h.sert
       if aranan_sertlik >= camasirsertligi[1][1][0] and aranan_sertlik <= camasirsertligi[1][1][1]:
           x=1-((1-0)*(camasirsertligi[1][1][0]-aranan_sertlik))/(camasirsertligi[1][1][0]-camasirsertligi[1][1][1])
           uyelikler.append(x) 
       else:
           x=1-((1-0)*(camasirsertligi[1][1][2]-aranan_sertlik))/(camasirsertligi[1][1][2]-camasirsertligi[1][1][1])
           uyelikler.append(x)
    if aranan_sertlik >= camasirsertligi[2][1][0] and aranan_sertlik <= camasirsertligi[2][1][2]: #40-80
       uyelikler.append(camasirsertligi[2][0]) #h.yumuşak
       if aranan_sertlik >= camasirsertligi[2][1][0] and aranan_sertlik <= camasirsertligi[2][1][1]:
           x=1-((1-0)*(camasirsertligi[2][1][0]-aranan_sertlik))/(camasirsertligi[2][1][0]-camasirsertligi[2][1][1])
           uyelikler.append(x) 
       else:
           x=1-((1-0)*(camasirsertligi[2][1][2]-aranan_sertlik))/(camasirsertligi[2][1][2]-camasirsertligi[2][1][1])
           uyelikler.append(x)
    if aranan_sertlik >= camasirsertligi[3][1][0] and aranan_sertlik <= camasirsertligi[3][1][2]: #60-100
       uyelikler.append(camasirsertligi[3][0])#yumuşak
       if aranan_sertlik >= camasirsertligi[3][1][0] and aranan_sertlik <= camasirsertligi[3][1][1]: 
           x=1-((1-0)*(camasirsertligi[3][1][0]-aranan_sertlik))/(camasirsertligi[3][1][0]-camasirsertligi[3][1][1])
           uyelikler.append(x) 
       else:
           uyelikler.append(1)
    return uyelikler

sertlik= camasirsertlikuye(camasirsertligi,aranan_sertlik)  # yumusağın 0.25 çıkması alazım
print(sertlik)
sertlik_de = [de for de in sertlik if isinstance(de, str)]  # Sadece string değerleri filtrele
print(sertlik_de)
# Out:
# ['h.sert', 0.5, 'h.yumuşak', 0.5]
# ['h.sert', 'h.yumuşak']

# %%
aranan_miktar=2
def camasirmiktariuye(camasirmiktari,aranan_miktar):
    uyelikler= list()

    if aranan_miktar >= camasirmiktari[0][1][0] and aranan_miktar <= camasirmiktari[0][1][2]:
       uyelikler.append(camasirmiktari[0][0])
       if aranan_miktar >= camasirmiktari[0][1][0] and aranan_miktar <= camasirmiktari[0][1][1]:
           uyelikler.append(1) 
       else:
           x=1-((1-0)*(camasirmiktari[0][1][2]-aranan_miktar))/(camasirmiktari[0][1][2]-camasirmiktari[0][1][0])
           uyelikler.append(x)
    
    if aranan_miktar >= camasirmiktari[1][1][0] and aranan_miktar <= camasirmiktari[1][1][2]:
       uyelikler.append(camasirmiktari[1][0])
       if aranan_miktar >= camasirmiktari[1][1][0] and aranan_miktar <= camasirmiktari[1][1][1]:
           x=1-((1-0)*(camasirmiktari[1][1][0]-aranan_miktar))/(camasirmiktari[1][1][0]-camasirmiktari[1][1][1])
           uyelikler.append(x) 
       else:
           x=1-((1-0)*(camasirmiktari[1][1][2]-aranan_miktar))/(camasirmiktari[1][1][2]-camasirmiktari[1][1][1])
           uyelikler.append(x)
          
    
    if aranan_miktar >= camasirmiktari[2][1][0] and aranan_miktar <= camasirmiktari[2][1][2]:
       uyelikler.append(camasirmiktari[2][0])
       if aranan_miktar >= camasirmiktari[2][1][0] and aranan_miktar <= camasirmiktari[2][1][1]:
           x=1-((1-0)*(camasirmiktari[2][1][0]-aranan_miktar))/(camasirmiktari[2][1][0]-camasirmiktari[2][1][1])
           uyelikler.append(x) 
       else:
           uyelikler.append(1)
           
    return uyelikler
y= camasirmiktariuye(camasirmiktari,aranan_miktar)
print(y)
miktar_de = [de for de in y if isinstance(de, str)] # Sadece string değerleri filtrele
miktar_de
# Out:
# ['az', 0.6666666666666667, 'normal', 0.5]
# ['az', 'normal']

# %%
hyumusak =0.50
yumusak=0.25
normal=0.50
cok=0.50

# %%
#kuralların belirlenmesi
liste=[]
liste1=[]

if sertlik_de[0] == "sert" or sertlik_de[1] == "sert":
    if miktar_de[0]=="az" or miktar_de[1] == "az":
        liste.append("camasirsertligi['sert'] | camasirmiktari['normal'], devir['güçlü']")# kuralın çıktısını göstermek için 
        devir=min(sert, az)
        liste1.append(f"güçlü Devir değeri: {devir}")
    if miktar_de[0] == "normal"or miktar_de[1]=="normal":
        liste.append("camasirsertligi['sert'] | camasirmiktari['normal'], devir['güçlü']")
        devir=min(sert, normal)
        liste1.append(f"Güçlü Devir değeri: {devir}")
    if miktar_de[0] == "çok" or miktar_de[1]=="çok":
        liste.append("camasirsertligi['sert'] | camasirmiktari['çok'], devir['güçlü'])")
        devir=min(sert, cok)
        liste1.append(f"Güçlü Devir değeri: {devir}")

if sertlik_de[0] == "h.sert" or sertlik_de[1] == "h.sert":
    if miktar_de[0] == "az" or miktar_de[1]=="az":
        liste.append("camasirsertligi['h.sert'] | camasirmiktari['az'], devir['normal']")
        devir=min(h.sert, az)
        liste1.append(f"Normal Devir değeri: {devir}")
    if miktar_de[0] == "normal"or miktar_de[1]=="normal":
        liste.append("camasirsertligi['h.sert'] | camasirmiktari['çok'], devir['güçlü']")
        devir=min(h.sert, normal)
        liste1.append(f"Hafif Devir değeri: {devir}")
    if miktar_de[0] == "çok" or miktar_de[1]=="çok":
        liste.append("camasirsertligi['h.yumuşak'] | camasirmiktari['az'], devir['hafif']")
        devir=min(h.sert, cok)
        liste1.append(f"Hafif Devir değeri: {devir}")


if sertlik_de[0]=="h.yumuşak" or sertlik_de[1]=="h.yumuşak":
    if miktar_de[0] == "az" or miktar_de[1]=="az":
        liste.append("camasirsertligi['h.yumuşak'] | camasirmiktari['az'], devir['hafif']")
        devir=min(hyumusak, az)
        liste1.append(f"Hafif Devir değeri: {devir}")
    if miktar_de[0] == "normal" or miktar_de[1]=="normal":
        liste.append("camasirsertligi['h.yumuşak'] , camasirmiktari['normal'], devir['hafif']")
        devir=min(hyumusak, normal)
        liste1.append(f"Hafif Devir değeri: {devir}")

    if miktar_de[0] == "çok" or miktar_de[1]=="çok":
        liste.append("camasirsertligi['h.yumuşak'] | camasirmiktari['çok'], devir['normal']")
        devir=min(hyumusak, cok)
        liste1.append(f"Normal Devir değeri: {devir}")


if sertlik_de[0]=="yumuşak" or sertlik_de[1]=="yumuşak":
    if miktar_de[0] == "az" or miktar_de[1]=="az":
        liste.append("(camasirsertligi['yumuşak'] | camasirmiktari['az'], devir['hassas'])")
        devir=min(yumusak, az)
        liste1.append(f"Hassas Devir değeri: {devir}")
    if miktar_de[0] == "normal" or miktar_de[1]=="normal":
        liste.append("camasirsertligi['yumuşak'] | camasirmiktari['normal'], devir['hassas']")
        devir=min(yumusak, normal)
        liste1.append(f"Hassas Devir değeri: {devir}")
    if miktar_de[0] == "çok" or miktar_de[1]=="çok":
        liste.append("camasirsertligi['yumuşak'] | camasirmiktari['çok'], devir['hafif']")
        devir=min(yumusak, cok)
        liste1.append((devir))


liste
liste1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 22
#      20 if miktar_de[0] == "az" or miktar_de[1]=="az":
#      21     liste.append("camasirsertligi['h.sert'] | camasirmiktari['az'], devir['normal']")
# ---> 22     devir=min(h.sert, az)
#      23     liste1.append(f"Normal Devir değeri: {devir}")
#      24 if miktar_de[0] == "normal"or miktar_de[1]=="normal":
#
# NameError: name 'h' is not defined
